# %%
#Sistema de locação de carros by Asimov Academy
import os

carros = [
        ('Chevrolet Tracker', 120 ),
        ('Chevrolet Onix', 90),
        ('Chevrolet Spin', 150),
        ('Hyundai Tucson', 120),
        ('Fiat Uno', 60),
        ('Fiat Mobi', 70),
        ('Fiat Pulse', 130)            
        ]

alugados = []

print('Bem-vindo à locadora de carros')
print('==============================')
print('O que deseja fazer?')
print('==============================')

opcoes = {'0': 'Mostrar portfólio',
         '1': 'Alugar um veículo',
         '2': 'Devolver um veículo'}

def mostrar_lista_de_carros(lista_de_carros):
    for i, car in enumerate(lista_de_carros):
        print('[{}] {} - R$ {} /dia.'.format(i, car[0], car[1]))
        
while True:
    os. system('clear')
    print('==============================')
    print('Bem-vindo à locadora de carros!')
    print('==============================')
    print('O que deseja fazer?')
    print('0 - Mostrar Portfólio | 1 - Alugar um carro | 2 - Devolver um carro')
    
    op = int(input())
    
    os.system('clear')
    
    if op == 0:
        mostrar_lista_de_carros(carros)
        
    elif op == 1:
        mostrar_lista_de_carros(carros)
        print('==============================')
        print('Escolha o código do carro:')
        cod_car = int(input())
        print('Por quantos dias quer alugar este veículo?')
        dias = int(input())
        os.system('clear')
        
        print('Você escolher {} por {} dias.'.format(carros[cod_car] [0], dias))
        print('O aluguel totaliza R$ {}. Deseja alugar?'.format(dias * carros[cod_car][1]))
        
        print('0 - sim | 2 - não')
        conf = int(input())
        if conf == 0:
            print('Parabéns você alugou o {} por {} dias.'.format(carros[cod_car][0], dias))
            alugados.append(carros.pop(cod_car))
            
    elif op == 2:
        if len(alugados) ==0:
            print('Não há carros para devolver!')
        else:
            print('Segue lista de carros alugados. Qual você deseja devolver?')
            mostrar_lista_de_carros(alugados)
            print('')
            print('Escolha o código do carro qe deseja devolver:')
            cod = int(input())
            if cod == 0:
                print('Obrigado por devolver o carro {}'.format(alugados[cod][0]))
                carros.append(alugados.pop(cod))
    
    print('')
    print('==============================')
    print('0 - continuar | 1 - sair')
    
    if float(input())== 1:
        break
# Out:
# Bem-vindo à locadora de carros
# ==============================
# O que deseja fazer?
# ==============================
# ==============================
# Bem-vindo à locadora de carros!
# ==============================
# O que deseja fazer?
# 0 - Mostrar Portfólio | 1 - Alugar um carro | 2 - Devolver um carro
# 1
# [0] Chevrolet Tracker - R$ 120 /dia.
# [1] Chevrolet Onix - R$ 90 /dia.
# [2] Chevrolet Spin - R$ 150 /dia.
# [3] Hyundai Tucson - R$ 120 /dia.
# [4] Fiat Uno - R$ 60 /dia.
# [5] Fiat Mobi - R$ 70 /dia.
# [6] Fiat Pulse - R$ 130 /dia.
# ==============================
# Escolha o código do carro:
# 0
# Por quantos dias quer alugar este veículo?
# 10
# Você escolher Chevrolet Tracker por 10 dias.
# O aluguel totaliza R$ 1200. Deseja alugar?
# 0 - sim | 2 - não
# 0
# Parabéns você alugou o Chevrolet Tracker por 10 dias.
#
# ==============================
# 0 - continuar | 1 - sair
# 0
# ==============================
# Bem-vindo à locadora de carros!
# ==============================
# O que deseja fazer?
# 0 - Mostrar Portfólio | 1 - Alugar um carro | 2 - Devolver um carro
# 2
# Segue lista de carros alugados. Qual você deseja devolver?
# [0] Chevrolet Tracker - R$ 120 /dia.
#
# Escolha o código do carro qe deseja devolver:
# 0
# Obrigado por devolver o carro Chevrolet Tracker
#
# ==============================
# 0 - continuar | 1 - sair
# 1
